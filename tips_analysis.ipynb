# %% [markdown]
# python in-built libraries:
# 1.pandas --data manipulation(load,view,clean,filtering,aggregate)
# 2.numpy--calculate big math(mean,standard deviation,etc)
# 3.matplotlib/seaborn--visualize the data

# %%
S1: LOAD DATA
pd.read_excel(r"file name")

# %%
import pandas as pd 
import numpy as np

df=pd.read_excel(r"C:\Users\91709\Downloads\tips.xlsx")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# STEP2:VIEW DATA/Exploring Data
# df.head()
# df.tail()
# df.info
# df.describe
# df.columns
# df.shape
# df.dtypes

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.shape
# Out:
# (244, 7)

# %%
df.shape[0]
# Out:
# 244

# %%
df.info
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# S3:SELCTING DATA
# df.iloc[0]
# df.iloc[:,1]
# df["col"]
# df.iloc[:,1:6]

# %%
df.iloc[0]   #1st row
# Out:
# total_bill     16.99
# tip             1.01
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 0, dtype: object

# %%
df['total_bill']  #1st column
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df.iloc[:,1:2]
# Out:
#       tip
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# ..    ...
# 239  5.92
# 240  2.00
# 241  2.00
# 242  1.75
# 243  3.00
#
# [244 rows x 1 columns]

# %% [markdown]
# S4:Filtering & Querying
# df.query("col > 100 and col2 == 'A'")   #multiple condition on column
# df[df['col'] > 100]   #single condition on column

# %%
f=df[df["total_bill"]>20.0]
f
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 7         26.88  3.12    Male     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
#
# [97 rows x 7 columns]

# %%
dd=df.query("total_bill > 10 and sex=='Male' and size==3 and smoker=='Yes'")  #multiple conditions on columns

# %%
# Out:
# 170    10.00
# 182     3.50
# 189     4.00
# 200     4.00
# 206     3.41
# 210     2.00
# 231     3.00
# Name: tip, dtype: float64

# %%
dd.shape   #outputs >>>(all rows,all columns)
# Out:
# (7, 7)

# %%
dd=dd[dd['tip']>5]
dd
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# S5:Modifying Data
#
# Modifying Data: This is where the structure or content of the DataFrame is actively changed. The sources detail several key modifications:
# ◦
# Creating New Columns:  (df['new'] = df['col1'] + df['col2']).
# ◦
# Renaming Columns:  (df.rename(columns={'old': 'new'})).
# ◦
# Dropping Columns:  (df.drop(columns=['col'])).
# ◦
# Handling Missing Values: Addressing gaps in the data by removing rows with missing data (df.dropna()) or replacing missing values with a specified value (df.fillna(0)).
# ◦
# Converting Data Types: Ensuring columns have the appropriate type for analysis or calculations (df.astype({'col': 'int'}))

# %%
df.rename(columns={"tip":"cst_tip"})
# Out:
#      total_bill  cst_tip     sex smoker   day    time  size
# 0         16.99     1.01  Female     No   Sun  Dinner     2
# 1         10.34     1.66    Male     No   Sun  Dinner     3
# 2         21.01     3.50    Male     No   Sun  Dinner     3
# 3         23.68     3.31    Male     No   Sun  Dinner     2
# 4         24.59     3.61  Female     No   Sun  Dinner     4
# ..          ...      ...     ...    ...   ...     ...   ...
# 239       29.03     5.92    Male     No   Sat  Dinner     3
# 240       27.18     2.00  Female    Yes   Sat  Dinner     2
# 241       22.67     2.00    Male    Yes   Sat  Dinner     2
# 242       17.82     1.75    Male     No   Sat  Dinner     2
# 243       18.78     3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df["bearer_total"]=df['total_bill']+df['tip']  #Creating New Columns:df['new'] = df['col1'] + df['col2']
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  bearer_total
# 0         16.99  1.01  Female     No   Sun  Dinner     2         18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3         12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3         24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2         26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4         28.20
# ..          ...   ...     ...    ...   ...     ...   ...           ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2         19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2         21.78
#
# [244 rows x 8 columns]

# %%
df.drop('day',axis=1)         #axis=1 is column #drop 'day' column
# Out:
#      total_bill   tip     sex smoker    time  size  bearer_total
# 0         16.99  1.01  Female     No  Dinner     2         18.00
# 1         10.34  1.66    Male     No  Dinner     3         12.00
# 2         21.01  3.50    Male     No  Dinner     3         24.51
# 3         23.68  3.31    Male     No  Dinner     2         26.99
# 4         24.59  3.61  Female     No  Dinner     4         28.20
# ..          ...   ...     ...    ...     ...   ...           ...
# 239       29.03  5.92    Male     No  Dinner     3         34.95
# 240       27.18  2.00  Female    Yes  Dinner     2         29.18
# 241       22.67  2.00    Male    Yes  Dinner     2         24.67
# 242       17.82  1.75    Male     No  Dinner     2         19.57
# 243       18.78  3.00  Female     No  Dinner     2         21.78
#
# [244 rows x 7 columns]

# %%
df.fillna(0)    #Handling missing values : fill the missing values by zero
# Out:
#      total_bill   tip     sex smoker   day    time  size  bearer_total
# 0         16.99  1.01  Female     No   Sun  Dinner     2         18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3         12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3         24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2         26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4         28.20
# ..          ...   ...     ...    ...   ...     ...   ...           ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2         19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2         21.78
#
# [244 rows x 8 columns]

# %%
df.astype({'tip':int})   #coverting column datatypes : df.astype({'col': 'int'})
# Out:
#      total_bill  tip     sex smoker   day    time  size  bearer_total
# 0         16.99    1  Female     No   Sun  Dinner     2         18.00
# 1         10.34    1    Male     No   Sun  Dinner     3         12.00
# 2         21.01    3    Male     No   Sun  Dinner     3         24.51
# 3         23.68    3    Male     No   Sun  Dinner     2         26.99
# 4         24.59    3  Female     No   Sun  Dinner     4         28.20
# ..          ...  ...     ...    ...   ...     ...   ...           ...
# 239       29.03    5    Male     No   Sat  Dinner     3         34.95
# 240       27.18    2  Female    Yes   Sat  Dinner     2         29.18
# 241       22.67    2    Male    Yes   Sat  Dinner     2         24.67
# 242       17.82    1    Male     No   Sat  Dinner     2         19.57
# 243       18.78    3  Female     No  Thur  Dinner     2         21.78
#
# [244 rows x 8 columns]

# %%
df.astype({"size":float})     #coverting datatypes : df.astype({'col': 'int'})
# Out:
#      total_bill   tip     sex smoker   day    time  size  bearer_total
# 0         16.99  1.01  Female     No   Sun  Dinner   2.0         18.00
# 1         10.34  1.66    Male     No   Sun  Dinner   3.0         12.00
# 2         21.01  3.50    Male     No   Sun  Dinner   3.0         24.51
# 3         23.68  3.31    Male     No   Sun  Dinner   2.0         26.99
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0         28.20
# ..          ...   ...     ...    ...   ...     ...   ...           ...
# 239       29.03  5.92    Male     No   Sat  Dinner   3.0         34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner   2.0         29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner   2.0         24.67
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0         19.57
# 243       18.78  3.00  Female     No  Thur  Dinner   2.0         21.78
#
# [244 rows x 8 columns]

# %% [markdown]
# S6:
# "Data Cleaning Tips" and "Statistical Summary" sections list operations frequently integrated into the data manipulation workflow using Pandas. These include identifying and removing duplicate rows (df.duplicated().sum(), df.drop_duplicates()), performing text manipulations like converting to lowercase (df['col'].str.lower()) or checking for substrings (df['col'].str.contains('txt')), getting frequency counts of values (df['col'].value_counts()), finding unique values (df['col'].unique()), and calculating the correlation matrix (df.corr()).

# %%
df["sex"].str.lower()  #converting to lowercase (df['col'].str.lower())
# Out:
# 0      female
# 1        male
# 2        male
# 3        male
# 4      female
#         ...
# 239      male
# 240    female
# 241      male
# 242      male
# 243    female
# Name: sex, Length: 244, dtype: object

# %%
df["sex"].str.contains('txt')  #check str contains any text
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: sex, Length: 244, dtype: bool

# %%
df["sex"].value_counts()     #getting frequency counts of values
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

#Define the variable sex and height before using them
sex = ['Male', 'Female']  # Replace with your actual data
height = [87, 157]   # Replace with your actual data


df.hist()
plt.bar(sex,height)

plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.barplot(data=df, x='day', y='tip', estimator='mean', palette='pastel')
plt.title('Average Tip by Day')
plt.xlabel('Day of Week')
plt.ylabel('Average Tip')
plt.show()

"""🧠 What it does:
Goal: Show the average amount of tips given on each day (e.g., Thurs, Fri, Sat, Sun).
plt.figure(figsize=(width, height))
figsize=(6, 4) means:
         Width = 6 inches
         Height = 4 inches
Controls the size of the plot output
x='day': Categorical variable on the x-axis (day of the week).

y='tip': Numerical variable on the y-axis (tip amount).

estimator='mean': Aggregates the data using the mean (average tip for each day).

palette='pastel': Sets soft, pastel colors for the bars."""
# Out:
# C:\Users\91709\AppData\Local\Temp\ipykernel_18788\2191343316.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='day', y='tip', estimator='mean', palette='pastel')
# "🧠 What it does:\nGoal: Show the average amount of tips given on each day (e.g., Thurs, Fri, Sat, Sun).\n\nx='day': Categorical variable on the x-axis (day of the week).\n\ny='tip': Numerical variable on the y-axis (tip amount).\n\nestimator='mean': Aggregates the data using the mean (average tip for each day).\n\npalette='pastel': Sets soft, pastel colors for the bars."

# %%
df["sex"].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
categories=["Male","Female"]
values=[157,87]
# Create a bar plot

# %%
plt.hist(df["total_bill"])   ###Histogram 

plt.show()

# %%
average_tip=df["tip"].mean()
average_tip
# Out:
# 2.99827868852459

# %%
# 8. Box plot: Tip distribution by gender
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x='sex', y='tip', palette='Set2')
plt.title('Tip Distribution by Gender')
plt.show()


"""
"""🧠 What it does:
Goal: Show how tip amounts are distributed for each gender (Male vs. Female).

x='sex': Gender on the x-axis (categorical).

y='tip': Tip amount on the y-axis (numeric).

sns.boxplot: Plots box-and-whiskers to show spread, median, and outliers.

palette='Set2': A Seaborn color palette.""""
# Out:
# C:\Users\91709\AppData\Local\Temp\ipykernel_18788\1678900219.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='sex', y='tip', palette='Set2')

# %%
# 9. Scatter plot: total_bill vs tip
plt.figure(figsize=(6, 4))
sns.scatterplot(data=df, x='total_bill', y='tip', hue='sex', style='smoker')
plt.title('Tip vs Total Bill')
plt.show()




"""🧠 What it does:
Goal: Visualize the relationship between the bill amount and the tip amount.

x='total_bill': Total bill value.

y='tip': Corresponding tip value.

hue='sex': Colors each point by gender (Male/Female).

style='smoker': Changes the marker shape based on smoker status."""
# Out:
# "🧠 What it does:\nGoal: Visualize the relationship between the bill amount and the tip amount.\n\nx='total_bill': Total bill value.\n\ny='tip': Corresponding tip value.\n\nhue='sex': Colors each point by gender (Male/Female).\n\nstyle='smoker': Changes the marker shape based on smoker status."
